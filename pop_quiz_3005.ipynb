# %% [markdown]
# Написать функцию, которая берёт на вход:
# 1. Временную последовательность (т.е. список из пар вида (время, значение))
# 2. Произвольное значение времени
#
# И возвращает значение последовательности в этот момент времени, вычисленное с помощью линейной интерполяции.
# Если значение времени меньше минимального или больше максимального в последовательности, то должна быть вызвана ошибка.

# %%
seq = [(i / 10, (i / 10) ** 3 - 2 * (i / 10) * 2 + 1) for i in range(100)]

# %%
print(seq)
# Out:
# [(0.0, 1.0), (0.1, 0.601), (0.2, 0.20799999999999996), (0.3, -0.17300000000000004), (0.4, -0.536), (0.5, -0.875), (0.6, -1.1840000000000002), (0.7, -1.4569999999999999), (0.8, -1.6880000000000002), (0.9, -1.871), (1.0, -2.0), (1.1, -2.069), (1.2, -2.072), (1.3, -2.003), (1.4, -1.8560000000000003), (1.5, -1.625), (1.6, -1.3039999999999994), (1.7, -0.8870000000000005), (1.8, -0.36799999999999944), (1.9, 0.25899999999999945), (2.0, 1.0), (2.1, 1.8610000000000007), (2.2, 2.8480000000000025), (2.3, 3.9669999999999987), (2.4, 5.223999999999998), (2.5, 6.625), (2.6, 8.176), (2.7, 9.883000000000003), (2.8, 11.751999999999995), (2.9, 13.789), (3.0, 16.0), (3.1, 18.391000000000005), (3.2, 20.968000000000007), (3.3, 23.737), (3.4, 26.703999999999994), (3.5, 29.875), (3.6, 33.25600000000001), (3.7, 36.85300000000001), (3.8, 40.672), (3.9, 44.718999999999994), (4.0, 49.0), (4.1, 53.52099999999998), (4.2, 58.28800000000001), (4.3, 63.30699999999999), (4.4, 68.58400000000003), (4.5, 74.125), (4.6, 
# ...

# %%
def interpolate(seq, val):
    pass

# %%
interpolate(seq, 0.15)
