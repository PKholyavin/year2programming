# %% [markdown]
# Задание:
#
# 1. Прочитать файл cta0003.wav и парный к нему cta0003.seg_B1 (разметка на звуки)
# 2. Разделить файл по меткам и записать каждый кусок в отдельный файл
# 3. Брать нужно только те метки, название которых не пустое
# 4. Количество получившихся файлов должно совпадать с количеством звуков в исходном файле
# 5. Поэтому подумайте, каким должно быть название каждого файла: оно должно быть (а) информативным и (б) уникальным
